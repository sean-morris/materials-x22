# %%
from datascience import *
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')

# %% [markdown]
# ## Introduction: Average (Mean) ##

# %% [markdown]
# **Please run all cells before this cell, including the import cell at the top of the notebook.**

# %%
values = make_array(2, 3, 3, 9)

# %%
sum(values) / len(values), np.average(values), np.mean(values)
# Out:
# (4.25, 4.25, 4.25)

# %%
(2 + 3 + 3 + 9) / 4
# Out:
# 4.25

# %%
2 * (1/4) + 3 * (2/4) + 9 * (1/4)
# Out:
# 4.25

# %%
2 * 0.25 + 3 * 0.5 + 9 * 0.25
# Out:
# 4.25

# %%
values_table = Table().with_columns('Value', values)
values_table
# Out:
# Value
# 2
# 3
# 3
# 9

# %%
bins_for_display = np.arange(0.5, 10.6, 1)

# %%
values_table.hist(bins = bins_for_display, ec = 'w')

# %%
2 * np.ones(10)
# Out:
# array([ 2.,  2.,  2.,  2.,  2.,  2.,  2.,  2.,  2.,  2.])

# %%
twos = 2 * np.ones(10)
threes = 3 * np.ones(20)
nines = 9 * np.ones(10)

# %%
new_values = np.append(np.append(twos, threes), nines)

# %%
len(new_values)
# Out:
# 40

# %%
new_values_table = Table().with_column('Value', new_values)
new_values_table.hist(bins = bins_for_display)

# %%
np.average(new_values), np.average(values)
# Out:
# (4.25, 4.25)

# %% [markdown]
# ## The Average and the Median ##

# %% [markdown]
# **Please run all cells before this cell, including the previous example cells and the import cell at the top of the notebook.**

# %%
nba = Table.read_table('nba2013.csv')

# %%
nba
# Out:
# Name            | Position | Height | Weight | Age in 2013
# DeQuan Jones    | Guard    | 80     | 221    | 23
# Darius Miller   | Guard    | 80     | 235    | 23
# Trevor Ariza    | Guard    | 80     | 210    | 28
# James Jones     | Guard    | 80     | 215    | 32
# Wesley Johnson  | Guard    | 79     | 215    | 26
# Klay Thompson   | Guard    | 79     | 205    | 23
# Thabo Sefolosha | Guard    | 79     | 215    | 29
# Chase Budinger  | Guard    | 79     | 218    | 25
# Kevin Martin    | Guard    | 79     | 185    | 30
# Evan Fournier   | Guard    | 79     | 206    | 20
# ... (495 rows omitted)

# %%
nba.hist('Height', bins=np.arange(65.5, 90.5), ec='w')

# %%
heights = nba.column('Height')
percentile(50, heights), np.average(heights)
# Out:
# (80, 79.065346534653472)

# %% [markdown]
# ## Standard Deviation ##

# %% [markdown]
# **Please run all cells before this cell, including the previous example cells and the import cell at the top of the notebook.**

# %%
sd_table = Table().with_columns('Value', values)
sd_table
# Out:
# Value
# 2
# 3
# 3
# 9

# %%
average = np.average(values)
average
# Out:
# 4.25

# %%
deviations = values - average
sd_table = sd_table.with_column('Deviation', deviations)
sd_table
# Out:
# Value | Deviation
# 2     | -2.25
# 3     | -1.25
# 3     | -1.25
# 9     | 4.75

# %%
sum(deviations)
# Out:
# 0.0

# %%
sd_table = sd_table.with_column('Squared Deviation', deviations ** 2)
sd_table
# Out:
# Value | Deviation | Squared Deviation
# 2     | -2.25     | 5.0625
# 3     | -1.25     | 1.5625
# 3     | -1.25     | 1.5625
# 9     | 4.75      | 22.5625

# %%
# Variance of the data is the average of the squared deviations

variance = np.average(sd_table.column('Squared Deviation'))
variance
# Out:
# 7.6875

# %%
# Standard Deviation (SD) is the square root of the variance

sd = variance ** 0.5
sd
# Out:
# 2.7726341266023544

# %%
np.std(values)
# Out:
# 2.7726341266023544

# %% [markdown]
# ## Chebyshev's Bounds ##

# %% [markdown]
# **Please run all cells before this cell, including the previous example cells and the import cell at the top of the notebook.**

# %%
births = Table.read_table('baby.csv')

# %%
births
# Out:
# Birth Weight | Gestational Days | Maternal Age | Maternal Height | Maternal Pregnancy Weight | Maternal Smoker
# 120          | 284              | 27           | 62              | 100                       | False
# 113          | 282              | 33           | 64              | 135                       | False
# 128          | 279              | 28           | 64              | 115                       | True
# 108          | 282              | 23           | 67              | 125                       | True
# 136          | 286              | 25           | 62              | 93                        | False
# 138          | 244              | 33           | 62              | 178                       | False
# 132          | 245              | 23           | 65              | 140                       | False
# 120          | 289              | 25           | 62              | 125                       | False
# 143          | 299              | 30           | 66              | 136                       | True
# 140          | 351              | 27           | 68              | 120                       | False
# ... (1164 rows omitted)

# %%
births.hist('Maternal Pregnancy Weight')

# %%
mpw = births.column('Maternal Pregnancy Weight')
average = np.average(mpw)
sd = np.std(mpw)
average, sd
# Out:
# (128.4787052810903, 20.725449704280411)

# %%
within_3_SDs = births.where('Maternal Pregnancy Weight', are.between(average - 3*sd, average + 3*sd))

# %%
within_3_SDs.num_rows / births.num_rows
# Out:
# 0.9863713798977853

# %%
# Chebyshev's bound for the proportion in the range "average plus or minus 3 SDs"
# is at least

1 - 1/3**2
# Out:
# 0.8888888888888888

# %%
births.hist(overlay = False)
# Out:
# /Users/sean/Documents/cb/materials-x22/.env/lib/python3.13/site-packages/matplotlib/axes/_axes.py:7129: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
#   m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Documents/cb/materials-x22/.env/lib/python3.13/site-packages/numpy/lib/_histograms_impl.py:350, in _unsigned_subtract(a, b)
#     349 try:
# --> 350     unsigned_dt = signed_to_unsigned[dt.type]
#     351 except KeyError:
#
# KeyError: <class 'numpy.bool'>
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 births.hist(overlay = False)
#
# File ~/Documents/cb/datascience/datascience/tables.py:5539, in Table.hist(self, overlay, bins, bin_column, unit, counts, group, rug, side_by_side, left_end, right_end, width, height, *columns, **vargs)
#    5535                 axis.scatter(values_for_hist, np.zeros_like(values_for_hist), marker="|",
#    5536                              color="black", s=100, zorder=10)
#    5537             type(self).plots.append(axis)
# -> 5539 draw_hist(values_dict)
#
# File ~/Documents/cb/datascience/datascience/tables.py:5528, in Table.hist.<locals>.draw_hist(values_dict)
#    5526     vargs['weights'] = weights[i]
#    5527 axis.set_xlabel(hist_name + x_unit, fontsize=16)
# -> 5528 heights, bins, patches = axis.hist(values_for_hist, color=color, **vargs)
#    5529 if left_end is not None and right_end is not None:
#    5530     x_shade, height_shade, width_shade = _compute_shading(heights, bins.copy(), left_end, right_end)
#
# File ~/Documents/cb/materials-x22/.env/lib/python3.13/site-packages/matplotlib/_api/deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File ~/Documents/cb/materials-x22/.env/lib/python3.13/site-packages/matplotlib/__init__.py:1521, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1518 @functools.wraps(func)
#    1519 def inner(ax, *args, data=None, **kwargs):
#    1520     if data is None:
# -> 1521         return func(
#    1522             ax,
#    1523             *map(cbook.sanitize_sequence, args),
#    1524             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1526     bound = new_sig.bind(ax, *args, **kwargs)
#    1527     auto_label = (bound.arguments.get(label_namer)
#    1528                   or bound.kwargs.get(label_namer))
#
# File ~/Documents/cb/materials-x22/.env/lib/python3.13/site-packages/matplotlib/axes/_axes.py:7129, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    7125 # Loop through datasets
#    7126 for i in range(nx):
#    7127     # this will automatically overwrite bins,
#    7128     # so that each histogram uses the same bins
# -> 7129     m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    7130     tops.append(m)
#    7131 tops = np.array(tops, float)  # causes problems later if it's an int
#
# File ~/Documents/cb/materials-x22/.env/lib/python3.13/site-packages/numpy/lib/_histograms_impl.py:827, in histogram(a, bins, range, density, weights)
#     825 # Pre-compute histogram scaling factor
#     826 norm_numerator = n_equal_bins
# --> 827 norm_denom = _unsigned_subtract(last_edge, first_edge)
#     829 # We iterate over blocks here for two reasons: the first is that for
#     830 # large arrays, it is actually faster (for example for a 10^8 array it
#     831 # is 2x as fast) and it results in a memory footprint 3x lower in the
#     832 # limit of large arrays.
#     833 for i in _range(0, len(a), BLOCK):
#
# File ~/Documents/cb/materials-x22/.env/lib/python3.13/site-packages/numpy/lib/_histograms_impl.py:352, in _unsigned_subtract(a, b)
#     350     unsigned_dt = signed_to_unsigned[dt.type]
#     351 except KeyError:
# --> 352     return np.subtract(a, b, dtype=dt)
#     353 else:
#     354     # we know the inputs are integers, and we are deliberately casting
#     355     # signed to unsigned.  The input may be negative python integers so
#     356     # ensure we pass in arrays with the initial dtype (related to NEP 50).
#     357     return np.subtract(np.asarray(a, dtype=dt), np.asarray(b, dtype=dt),
#     358                        casting='unsafe', dtype=unsigned_dt)
#
# TypeError: numpy boolean subtract, the `-` operator, is not supported, use the bitwise_xor, the `^` operator, or the logical_xor function instead.

# %%
# See if Chebyshev's bounds work
# for different shapes of distributions

for k in births.labels:
    values = births.column(k)
    average = np.average(values)
    sd = np.std(values)
    print()
    print(k)
    for z in np.arange(2, 6):
        chosen = births.where(k, are.between(average - z*sd, average + z*sd))
        proportion = chosen.num_rows / births.num_rows
        percent = round(proportion * 100, 2)
        print('Average plus or minus', z, 'SDs:', percent, '%')
